# %% [markdown]
# # Асосҳои Pandas

# %% [markdown]
# Тартибдиҳанда: Ҳакимов Раҳматҷон. Email: rahmatjon@gmail.com. Telegram: https://t.me/rahmatjon_hakimov
#
# ![cc-by-sa.png](attachment:1ebfb0f4-b16f-42b7-bfb2-4c5d6b9cc1d6.png)

# %% [markdown]
# Дар ин ноутбук мо бо имкониятҳои асосии `pandas` шинос хоҳем шуд. Ин модул ҳаҷми бузург дорад, бинобар ин мо танҳо як миқдори маҳдуди онро меомӯзем ва машқ мекунем. [Маълумоти муфассал](https://pandas.pydata.org/docs/reference/index.html)

# %% [markdown]
# # Шиносоии аввалин

# %% [markdown]
# Барои насби pandas дар муҳити оператсионӣ фармони зеринро иҷро намоед:
#
# pip install pandas
#
# ё ки
#
# pip install pandas[excel]

# %%
# !pip install pandas[excel]

# %% [markdown]
# Истифодаи pandas-ро эълон мекунем:

# %%
import pandas as pd  # pd лақаб барои pandas

# %% [markdown]
# Маълумотро аз csv-файл мехонем:

# %%
data = pd.read_csv('purchases.csv', sep = ';')

# %% [markdown]
# Дар тағйирёбандаи data чӣ ҳаст?

# %%
data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# ...

# %% [markdown]
# Аз ин чоп тасаввуроти умумӣ оиди мӯҳтавои файли purchases.csv гирифтан мумкин аст.

# %% [markdown]
# Аён аст, ки дар ҷадвал ҳам маълумоти ададӣ ва ҳам маълумоти сифатӣ/сатрӣ нигоҳ дошта шуда метавонад.

# %% [markdown]
# Намуди тағйирёбандаи data:

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Шарҳи маълумоти дар сутунҳо сабтшуда:
#  - *date* - санаи харид
#  - *item* - номгӯи маҳсулот
#  - *volume* - миқдори харидашуда
#  - *price* - нарх
#  - *market* - мағоза

# %% [raw]
# Андозаи ҷадвалро мебинем:

# %%
data.shape
# Out:
# (25, 5)

# %% [markdown]
# Барои чоп кардани ҳамагӣ якчанд сатри ҷадвал аз методи `head` истифода мебарем:

# %%
data.head()
# Out:
#          date                                      item  volume  price  \
# 0  2024-06-27  Плит шок Нестле 82гр Горький шоколад 70%   1.000   7.47
# 1  2024-06-27                           Огурцы Орзу 104   0.398   5.50
# 2  2024-06-27                             Огурцы Т 3960   0.394   4.95
# 3  2024-06-27                             Гелос 1 (492)   0.306  34.90
# 4  2024-06-27                             Помидор 103 м   0.962   3.80
#
#        market
# 0  Амид 19мкр
# 1  Амид 19мкр
# 2  Амид 19мкр
# 3  Амид 19мкр
# 4  Амид 19мкр

# %%
data.head(4)
# Out:
#          date                                      item  volume  price  \
# 0  2024-06-27  Плит шок Нестле 82гр Горький шоколад 70%   1.000   7.47
# 1  2024-06-27                           Огурцы Орзу 104   0.398   5.50
# 2  2024-06-27                             Огурцы Т 3960   0.394   4.95
# 3  2024-06-27                             Гелос 1 (492)   0.306  34.90
#
#        market
# 0  Амид 19мкр
# 1  Амид 19мкр
# 2  Амид 19мкр
# 3  Амид 19мкр

# %% [markdown]
# Тағйирёбандаи data ва натиҷаи data.head() як намуд доранд:

# %%
type(data.head())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Барои гирифтани маълумот оиди мӯҳтавои ҷадвал аз методи `info` истифода мебаранд:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    22 non-null     object
#  1   item    24 non-null     object
#  2   volume  25 non-null     float64
#  3   price   25 non-null     float64
#  4   market  22 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 1.1+ KB

# %% [markdown]
# Омори (статистикаи) содда барои майдонҳои ададии ҷадвали data (методи `describe`):

# %%
data.describe()
# Out:
#           volume       price
# count  25.000000   25.000000
# mean    0.875760   24.082800
# std     0.774244   35.042637
# min     0.208000    0.150000
# 25%     0.350000    3.800000
# 50%     1.000000    9.450000
# 75%     1.000000   22.000000
# max     4.000000  120.600000

# %%
y = data.head(6)
y.describe()
# Out:
#          volume      price
# count  6.000000   6.000000
# mean   0.621333  12.153333
# std    0.304175  12.020585
# min    0.306000   3.800000
# 25%    0.395000   5.087500
# 50%    0.533000   6.485000
# 75%    0.888500  14.092500
# max    1.000000  34.900000

# %%
y
# Out:
#          date                                      item  volume  price  \
# 0  2024-06-27  Плит шок Нестле 82гр Горький шоколад 70%   1.000   7.47
# 1  2024-06-27                           Огурцы Орзу 104   0.398   5.50
# 2  2024-06-27                             Огурцы Т 3960   0.394   4.95
# 3  2024-06-27                             Гелос 1 (492)   0.306  34.90
# 4  2024-06-27                             Помидор 103 м   0.962   3.80
# 5         NaN                            Болгарский 407   0.668  16.30
#
#        market
# 0  Амид 19мкр
# 1  Амид 19мкр
# 2  Амид 19мкр
# 3  Амид 19мкр
# 4  Амид 19мкр
# 5  Амид 19мкр

# %% [markdown]
# Сутуни алоҳидаи DataFrame тавассути номаш дастрас мешавад:

# %%
data['price']

# %%
type(data['price'])
# Out:
# pandas.core.series.Series

# %%
dir(data)

# %% [markdown]
# Бо сутунҳо амалҳоро элемент-ба-элемент иҷро кардан мумкин аст:

# %%
data['price'] * data['volume']
# Out:
# 0      7.4700
# 1      2.1890
# 2      1.9503
# 3     10.6794
# 4      3.6556
# 5     10.8884
# 6      0.2000
# 7     11.5000
# 8      9.4500
# 9      6.8600
# 10    24.0864
# 11    15.9600
# 12    32.3360
# 13    27.4968
# 14     1.1172
# 15    24.7604
# 16    16.0000
# 17    12.4000
# 18     3.4500
# 19    22.0000
# 20     0.1500
# 21    10.2336
# 22     1.6000
# 23     2.5500
# 24    10.5500
# dtype: float64

# %% [markdown]
# Ба ҷадвали data сутуни нав илова кардан мумкин аст:

# %%
data['summa'] = data['price'] * data['volume']
data.head(10)
# Out:
#          date                                      item  volume  price  \
# 0  2024-06-27  Плит шок Нестле 82гр Горький шоколад 70%   1.000   7.47
# 1  2024-06-27                           Огурцы Орзу 104   0.398   5.50
# 2  2024-06-27                             Огурцы Т 3960   0.394   4.95
# 3  2024-06-27                             Гелос 1 (492)   0.306  34.90
# 4  2024-06-27                             Помидор 103 м   0.962   3.80
# 5         NaN                            Болгарский 407   0.668  16.30
# 6  2024-05-17                                       NaN   1.000   0.20
# 7  2024-05-09                          Пряники "Ягодка"   1.000  11.50
# 8  2024-05-09      Напиток "Fanta" апельсин-яблоко 1,25   1.000   9.45
# 9  2024-05-09                              Помидоры т/т   0.350  19.60
#
#        market    summa
# 0  Амид 19мкр   7.4700
# 1  Амид 19мкр   2.1890
# 2  Амид 19мкр   1.9503
# 3  Амид 19мкр  10.6794
# 4  Амид 19мкр   3.6556
# 5  Амид 19мкр  10.8884
# ...

# %% [markdown]
# Ҳамаи тағйиротҳои ҷадвал дар хотираи фаврӣ (дар тағйирёбандаҳо Python) нигоҳ дошта мешаванд; ба маълумоти файл таъсир намерасонанд:

# %%
demo_data = pd.read_csv('purchases.csv', sep = ';')
demo_data.columns
# Out:
# Index(['date', 'item', 'volume', 'price', 'market'], dtype='object')

# %% [markdown]
# Маълумоти ҳисобшударо дар файли нав сабт мекунем:

# %%
data.to_csv('purchases_new.csv', sep=';', index=False, encoding='utf-8')
# data.to_csv('purchases_new.csv', sep=';', encoding='utf-8')

# %% [markdown]
# Сутуни ҷадвалро бо воситаи `del` ё методи `pop` хориҷ (delete) кардан мумкин аст:

# %%
#del data['market']  # Тарзи дигар: data.pop('market')
#data.pop('summa')

# %%
data.head()
# Out:
#          date                                      item  volume  price  \
# 0  2024-06-27  Плит шок Нестле 82гр Горький шоколад 70%   1.000   7.47
# 1  2024-06-27                           Огурцы Орзу 104   0.398   5.50
# 2  2024-06-27                             Огурцы Т 3960   0.394   4.95
# 3  2024-06-27                             Гелос 1 (492)   0.306  34.90
# 4  2024-06-27                             Помидор 103 м   0.962   3.80
#
#        market    summa
# 0  Амид 19мкр   7.4700
# 1  Амид 19мкр   2.1890
# 2  Амид 19мкр   1.9503
# 3  Амид 19мкр  10.6794
# 4  Амид 19мкр   3.6556

# %%
data['summa_10%'] = data['summa'] * 0.1
data.head(10)
# Out:
#          date                                      item  volume  price  \
# 0  2024-06-27  Плит шок Нестле 82гр Горький шоколад 70%   1.000   7.47
# 1  2024-06-27                           Огурцы Орзу 104   0.398   5.50
# 2  2024-06-27                             Огурцы Т 3960   0.394   4.95
# 3  2024-06-27                             Гелос 1 (492)   0.306  34.90
# 4  2024-06-27                             Помидор 103 м   0.962   3.80
# 5         NaN                            Болгарский 407   0.668  16.30
# 6  2024-05-17                                       NaN   1.000   0.20
# 7  2024-05-09                          Пряники "Ягодка"   1.000  11.50
# 8  2024-05-09      Напиток "Fanta" апельсин-яблоко 1,25   1.000   9.45
# 9  2024-05-09                              Помидоры т/т   0.350  19.60
#
#        market    summa  summa_10%
# 0  Амид 19мкр   7.4700    0.74700
# 1  Амид 19мкр   2.1890    0.21890
# 2  Амид 19мкр   1.9503    0.19503
# 3  Амид 19мкр  10.6794    1.06794
# ...

# %% [markdown]
# Сутунҳои ҷадвали pandas ҳамчун массиви дарозиаш тағйирёбанда ҳастанд. Сутунҳо соҳиби бисёр методҳои барои аналитика/таҳлил муфид мебошанд:

# %%
data['item']
# Out:
# 0           Плит шок Нестле 82гр Горький шоколад 70%
# 1                                    Огурцы Орзу 104
# 2                                      Огурцы Т 3960
# 3                                      Гелос 1 (492)
# 4                                      Помидор 103 м
# 5                                     Болгарский 407
# 6                                                NaN
# 7                                   Пряники "Ягодка"
# 8               Напиток "Fanta" апельсин-яблоко 1,25
# 9                                       Помидоры т/т
# 10               Конфеты "Бабаевские" трюфел/крем РТ
# 11                           Конфеты "Тотти" Suvorov
# 12        Конфеты "Бабаевские" с фундуком и какао РТ
# 13    Конфеты "Вдохновение" Миндаль и Фундук Крем РТ
# 14                                        Огурцы т/т
# 15                                            БАНАНЫ
# 16                              Напиток "RC Cola" 1л
# 17            Мороженое "Ты+Я" Дусти Алишер (565828)
# ...

# %%
type(data['item'])
# Out:
# pandas.core.series.Series

# %%
demo_data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# ...

# %%
help(pd.core.series.Series.value_counts)
# Out:
# Help on function value_counts in module pandas.core.base:
#
# value_counts(self, normalize: 'bool' = False, sort: 'bool' = True, ascending: 'bool' = False, bins=None, dropna: 'bool' = True) -> 'Series'
#     Return a Series containing counts of unique values.
#
#     The resulting object will be in descending order so that the
#     first element is the most frequently-occurring element.
#     Excludes NA values by default.
#
#     Parameters
#     ----------
#     normalize : bool, default False
#         If True then the object returned will contain the relative
#         frequencies of the unique values.
#     sort : bool, default True
#         Sort by frequencies.
#     ascending : bool, default False
#         Sort in ascending order.
#     bins : int, optional
#         Rather than count values, group them into half-open bins,
#         a convenience for ``pd.cut``, only works with numeric data.
#     dropna : bool, default True
#         Don't include counts of NaN.
#
# ...

# %%
type(demo_data['market'].value_counts())
# Out:
# pandas.core.series.Series

# %%
demo_data['market']
# Out:
# 0     Амид 19мкр
# 1     Амид 19мкр
# 2     Амид 19мкр
# 3     Амид 19мкр
# 4     Амид 19мкр
# 5     Амид 19мкр
# 6     Амид 19мкр
# 7           Доро
# 8           Доро
# 9           Доро
# 10          Доро
# 11          Доро
# 12          Доро
# 13          Доро
# 14          Доро
# 15          Доро
# 16          Доро
# 17         Оазис
# 18         Оазис
# 19         Оазис
# 20         Оазис
# 21           NaN
# 22           NaN
# 23           NaN
# 24          Доро
# Name: market, dtype: object

# %%
demo_data['market'].value_counts()
# Out:
# market
# Доро          11
# Амид 19мкр     7
# Оазис          4
# Name: count, dtype: int64

# %%
demo_data['market'].value_counts(dropna=False)
# Out:
# market
# Доро          11
# Амид 19мкр     7
# Оазис          4
# NaN            3
# Name: count, dtype: int64

# %%
demo_data['market'].value_counts()['Доро']
# Out:
# 11

# %%
demo_data['volume'].value_counts()
# Out:
# volume
# 1.000    10
# 0.228     2
# 0.398     1
# 0.394     1
# 0.306     1
# 0.962     1
# 0.668     1
# 0.350     1
# 0.208     1
# 0.280     1
# 0.344     1
# 1.036     1
# 2.000     1
# 4.000     1
# 0.492     1
# Name: count, dtype: int64

# %%
demo_data['volume'].value_counts(dropna=False)
# Out:
# volume
# 1.000    10
# 0.228     2
# 0.398     1
# 0.394     1
# 0.306     1
# 0.962     1
# 0.668     1
# 0.350     1
# 0.208     1
# 0.280     1
# 0.344     1
# 1.036     1
# 2.000     1
# 4.000     1
# 0.492     1
# Name: count, dtype: int64

# %%
date_group = demo_data['date'].value_counts(dropna=False)
date_group
# Out:
# date
# 2024-05-09    10
# 2024-06-27     5
# 2024-07-15     4
# NaN            3
# 2024-05-17     1
# 2024-05-29     1
# 2024-04-29     1
# Name: count, dtype: int64

# %%
type(date_group)
# Out:
# pandas.core.series.Series

# %%
date_group
# Out:
# date
# 2024-05-09    10
# 2024-06-27     5
# 2024-07-15     4
# NaN            3
# 2024-05-17     1
# 2024-05-29     1
# 2024-04-29     1
# Name: count, dtype: int64

# %%
#demo_data
#demo_data['date']
demo_data['date'].value_counts()['2024-06-27']
# Out:
# 5

# %%
#data['price'].sort_values(ascending = True)
data['price'].sort_values(ascending = False).head(5)
# Out:
# 13    120.6
# 10    115.8
# 12     94.0
# 11     57.0
# 3      34.9
# Name: price, dtype: float64

# %%
demo_data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# ...

# %%
data['price'].sort_values(ascending = False)[:5]
# Out:
# 13    120.6
# 10    115.8
# 12     94.0
# 11     57.0
# 3      34.9
# Name: price, dtype: float64

# %%
data['price'].sort_values(ascending = False).tail(5)
# Out:
# 17    3.10
# 23    2.55
# 22    1.60
# 6     0.20
# 20    0.15
# Name: price, dtype: float64

# %%
data.sort_values(ascending = False, by = 'summa')
# Out:
#           date                                            item  volume  \
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 15  2024-05-09                                          БАНАНЫ   1.036
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 19  2024-07-15                             Тухм 30 шт (566084)   1.000
# 16  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 5          NaN                                  Болгарский 407   0.668
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 24  2024-04-29                                 пряники "Асали"   1.000
# ...

# %%
demo_data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# ...

# %%
demo_data.sort_values(ascending = False, by = 'market')

# %%
demo_data.sort_values(['market','price'], ascending=[True, False])
# Out:
#           date                                            item  volume  \
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 5          NaN                                  Болгарский 407   0.668
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 4   2024-06-27                                   Помидор 103 м   0.962
# 6   2024-05-17                                             NaN   1.000
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 15  2024-05-09                                          БАНАНЫ   1.036
# ...

# %%
date_group = demo_data['date'].value_counts(dropna=False)
#date_group
date_group.sort_values()
# Out:
# date
# 2024-05-29     1
# 2024-04-29     1
# 2024-05-17     1
# NaN            3
# 2024-07-15     4
# 2024-06-27     5
# 2024-05-09    10
# Name: count, dtype: int64

# %% [markdown]
# Шарти аз 6 сомонӣ зиёд будани ҳаҷми харид. Шарти summa > 6:

# %%
data['summa'] > 6
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14    False
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24     True
# Name: summa, dtype: bool

# %% [markdown]
# Маълумот оиди хариде, ки суммааш аз 6 сомони зиёд аст. Ҷадвали натиҷавӣ аз рӯи майдони summa ба тариқи камшавӣ ба тартиб оварда шудааст:

# %%
data[data['summa'] > 6].sort_values(ascending = False, by = 'summa')
# Out:
#           date                                            item  volume  \
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# 15  2024-05-09                                          БАНАНЫ   1.036
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 19  2024-07-15                             Тухм 30 шт (566084)   1.000
# 16  2024-05-09                            Напиток "RC Cola" 1л   2.000
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 17  2024-07-15          Мороженое "Ты+Я" Дусти Алишер (565828)   4.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 5          NaN                                  Болгарский 407   0.668
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 24  2024-04-29                                 пряники "Асали"   1.000
# ...

# %% [markdown]
# Маълумот оиди харид аз мағозаҳои 'Доро' ва 'Оазис':

# %%
#demo_data
#demo_data['market'].isin(['Доро', 'Оазис'])
#demo_data[demo_data['market'].isin(['Оазис'])]
#demo_data[demo_data['market'].isin(['Доро', 'Оазис'])]
#demo_data[demo_data['market'].isin(['Амид'])]
#demo_data[demo_data['market'].str.contains("мид")]
#df[df['A'].str.contains("hello")]
#demo_data_WO_NaN = demo_data.dropna()
#demo_data_WO_NaN[demo_data_WO_NaN['market'].str.contains("Амид")]

# %%
data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# ...

# %%
#data['summa']
#data['summa'] = data['summa'].map(lambda x: round(x,2))
data['summa'] = round(data['summa'],1)

# %%
data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# ...

# %%
data.to_csv('purchases_new.csv', sep=';', index=False, encoding='utf-8')

# %%
data.to_excel('purchases_new.xlsx')

# %%
data.to_excel('purchases_new_2.xlsx', index=False)

# %%
data_xls = pd.read_excel('purchases_new.xlsx')

# %%
data_xls
# Out:
#     Unnamed: 0        date                                            item  \
# 0            0  2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%
# 1            1  2024-06-27                                 Огурцы Орзу 104
# 2            2  2024-06-27                                   Огурцы Т 3960
# 3            3  2024-06-27                                   Гелос 1 (492)
# 4            4  2024-06-27                                   Помидор 103 м
# 5            5         NaN                                  Болгарский 407
# 6            6  2024-05-17                                             NaN
# 7            7  2024-05-09                                Пряники "Ягодка"
# 8            8  2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25
# 9            9  2024-05-09                                    Помидоры т/т
# 10          10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ
# ...

# %%
data
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 5          NaN                                  Болгарский 407   0.668
# 6   2024-05-17                                             NaN   1.000
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# ...

# %%
help(pd.DataFrame.dropna)

# %%
data_WO_NaN = data.dropna()

# %%
data_WO_NaN
# Out:
#           date                                            item  volume  \
# 0   2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%   1.000
# 1   2024-06-27                                 Огурцы Орзу 104   0.398
# 2   2024-06-27                                   Огурцы Т 3960   0.394
# 3   2024-06-27                                   Гелос 1 (492)   0.306
# 4   2024-06-27                                   Помидор 103 м   0.962
# 7   2024-05-09                                Пряники "Ягодка"   1.000
# 8   2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25   1.000
# 9   2024-05-09                                    Помидоры т/т   0.350
# 10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ   0.208
# 11  2024-05-09                         Конфеты "Тотти" Suvorov   0.280
# 12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ   0.344
# 13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ   0.228
# ...

# %%
data_xls
# Out:
#     Unnamed: 0        date                                            item  \
# 0            0  2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%
# 1            1  2024-06-27                                 Огурцы Орзу 104
# 2            2  2024-06-27                                   Огурцы Т 3960
# 3            3  2024-06-27                                   Гелос 1 (492)
# 4            4  2024-06-27                                   Помидор 103 м
# 5            5         NaN                                  Болгарский 407
# 6            6  2024-05-17                                             NaN
# 7            7  2024-05-09                                Пряники "Ягодка"
# 8            8  2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25
# 9            9  2024-05-09                                    Помидоры т/т
# 10          10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ
# ...

# %%
data_xls.isnull()
# Out:
#     Unnamed: 0   date   item  volume  price  summa
# 0        False  False  False   False  False  False
# 1        False  False  False   False  False  False
# 2        False  False  False   False  False  False
# 3        False  False  False   False  False  False
# 4        False  False  False   False  False  False
# 5        False   True  False   False  False  False
# 6        False  False   True   False  False  False
# 7        False  False  False   False  False  False
# 8        False  False  False   False  False  False
# 9        False  False  False   False  False  False
# 10       False  False  False   False  False  False
# 11       False  False  False   False  False  False
# 12       False  False  False   False  False  False
# 13       False  False  False   False  False  False
# 14       False  False  False   False  False  False
# 15       False  False  False   False  False  False
# 16       False  False  False   False  False  False
# ...

# %%
data_xls = pd.read_excel('purchases_new.xlsx')
data_xls
# Out:
#     Unnamed: 0        date                                            item  \
# 0            0  2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%
# 1            1  2024-06-27                                 Огурцы Орзу 104
# 2            2  2024-06-27                                   Огурцы Т 3960
# 3            3  2024-06-27                                   Гелос 1 (492)
# 4            4  2024-06-27                                   Помидор 103 м
# 5            5         NaN                                  Болгарский 407
# 6            6  2024-05-17                                             NaN
# 7            7  2024-05-09                                Пряники "Ягодка"
# 8            8  2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25
# 9            9  2024-05-09                                    Помидоры т/т
# 10          10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ
# ...

# %%
#data_xls[(data_xls['price']>20)]
#data_xls[(data_xls['market'] == 'Доро')]
data_xls[(data_xls['price']>20) & (data_xls['market'] == 'Доро')]
# Out:
#     Unnamed: 0        date                                            item  \
# 10          10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ
# 11          11  2024-05-09                         Конфеты "Тотти" Suvorov
# 12          12  2024-05-09      Конфеты "Бабаевские" с фундуком и какао РТ
# 13          13  2024-05-09  Конфеты "Вдохновение" Миндаль и Фундук Крем РТ
# 15          15  2024-05-09                                          БАНАНЫ
#
#     volume  price market  summa
# 10   0.208  115.8   Доро   24.1
# 11   0.280   57.0   Доро   16.0
# 12   0.344   94.0   Доро   32.3
# 13   0.228  120.6   Доро   27.5
# 15   1.036   23.9   Доро   24.8

# %%
#import datetime
#data_xls
#datetime.datetime.now()
#datetime.datetime.now().date()
data_xls["date"] = data_xls["date"].fillna(datetime.datetime.now().date())

# %%
data_xls
# Out:
#     Unnamed: 0        date                                            item  \
# 0            0  2024-06-27        Плит шок Нестле 82гр Горький шоколад 70%
# 1            1  2024-06-27                                 Огурцы Орзу 104
# 2            2  2024-06-27                                   Огурцы Т 3960
# 3            3  2024-06-27                                   Гелос 1 (492)
# 4            4  2024-06-27                                   Помидор 103 м
# 5            5  2024-11-20                                  Болгарский 407
# 6            6  2024-05-17                                             NaN
# 7            7  2024-05-09                                Пряники "Ягодка"
# 8            8  2024-05-09            Напиток "Fanta" апельсин-яблоко 1,25
# 9            9  2024-05-09                                    Помидоры т/т
# 10          10  2024-05-09             Конфеты "Бабаевские" трюфел/крем РТ
# ...

# %%
help(pd.core.frame.DataFrame.loc)

# %%
help(pd.core.frame.DataFrame.iloc)
